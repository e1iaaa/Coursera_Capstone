# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import pandas as pd
import matplotlib.pyplot as plt

print('Imported.')
# Out:
# Imported.

# %%
pip install lxml html5lib beautifulsoup4
# Out:
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (4.5.1)
# Requirement already satisfied: html5lib in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from beautifulsoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# The code was removed by Watson Studio for sharing.

# %%
#Download Bangkok, Thailand list of Districts 
url = 'https://en.wikipedia.org/wiki/List_of_districts_of_Bangkok'
dfs = pd.read_html(url)
print(dfs[0])
# Out:
#           District(Khet)  MapNr  Post-code               Thai  Popu-lation  \
# 0               Bang Bon     50      10150             บางบอน       105161
# 1              Bang Kapi      6      10240            บางกะปิ       148465
# 2              Bang Khae     40      10160              บางแค       191781
# 3              Bang Khen      5      10220             บางเขน       189539
# 4          Bang Kho Laem     31      10120          บางคอแหลม        94956
# 5        Bang Khun Thian     21      10150        บางขุนเทียน       165491
# 6                Bang Na     47      10260              บางนา        95912
# 7             Bang Phlat     25      10700            บางพลัด        99273
# 8               Bang Rak      4      10500             บางรัก        45875
# 9               Bang Sue     29      10800            บางซื่อ       132234
# 10           Bangkok Noi     20      10700         บางกอกน้อย       117793
# 11           Bangkok Yai     16      10600         บางกอกใหญ่        72321
# 12             Bueng Kum     27      10240            บึงกุ่ม       145830
# 13             Chatuchak     30      10900            จตุจักร       160906
# 14            Chom Thong     35      10150             จอมทอง       158005
# 15             Din Daeng     26      10400             ดินแดง       130220
# 16            Don Mueang     36      10210           ดอนเมือง       166261
# 17                 Dusit      2      10300              ดุสิต       107655
# 18           Huai Khwang     17      10310           ห้วยขวาง        78175
# 19           Khan Na Yao     43      10230           คันนายาว        88678
# 20         Khlong Sam Wa     46      10510          คลองสามวา       169489
# 21            Khlong San     18      10600            คลองสาน        76446
# 22           Khlong Toei     33      10110            คลองเตย       109041
# 23                Lak Si     41      10210            หลักสี่       109770
# 24           Lat Krabang     11      10520          ลาดกระบัง       163175
# 25             Lat Phrao     38      10230           ลาดพร้าว       122182
# 26              Min Buri     10      10510            มีนบุรี       137251
# 27             Nong Chok      3      10530            หนองจอก       157138
# 28            Nong Khaem     23      10160            หนองแขม       150218
# 29            Pathum Wan      7      10330            ปทุมวัน        53263
# 30         Phasi Charoen     22      10160          ภาษีเจริญ       129827
# 31            Phaya Thai     14      10400              พญาไท        72952
# 32          Phra Khanong      9      10260            พระโขนง        93482
# 33           Phra Nakhon      1      10200             พระนคร        57876
# 34  Pom Prap Sattru Phai      8      10100  ป้อมปราบศัตรูพ่าย        51006
# 35                Prawet     32      10250             ประเวศ       160671
# 36            Rat Burana     24      10140        ราษฏร์บูรณะ        86695
# 37           Ratchathewi     37      10400            ราชเทวี        73035
# 38               Sai Mai     42      10220             สายไหม       188123
# 39        Samphanthawong     13      10100        สัมพันธวงศ์        27452
# 40           Saphan Sung     44      10240           สะพานสูง        89825
# 41                Sathon     28      10120               สาทร        84916
# 42            Suan Luang     34      10250            สวนหลวง       115658
# 43           Taling Chan     19      10170           ตลิ่งชัน       106604
# 44        Thawi Watthana     48      10170           ทวีวัฒนา        76351
# 45             Thon Buri     15      10600             ธนบุรี       119708
# 46            Thung Khru     49      10140            ทุ่งครุ       116473
# 47        Wang Thonglang     45      10310         วังทองหลาง       114768
# 48              Watthana     39      10110              วัฒนา        81623
# 49              Yan Nawa     12      10120            ยานนาวา        81521
#
#     No. ofSubdis-trictsKhwaeng   Latitude   Longitude
# 0                            4  13.659200  100.399100
# 1                            2  13.765833  100.647778
# 2                            4  13.696111  100.409444
# 3                            2  13.873889  100.596389
# 4                            3  13.693333  100.502500
# 5                            2  13.660833  100.435833
# 6                            2  13.680081  100.591800
# 7                            4  13.793889  100.505000
# 8                            5  13.730833  100.524167
# 9                            2  13.809722  100.537222
# 10                           5  13.770867  100.467933
# 11                           2  13.722778  100.476389
# 12                           3  13.785278  100.669167
# 13                           5  13.828611  100.559722
# 14                           4  13.677222  100.484722
# 15                           2  13.769722  100.552778
# 16                           3  13.913611  100.589722
# 17                           5  13.776944  100.520556
# 18                           3  13.776667  100.579444
# 19                           2  13.827100  100.674300
# 20                           5  13.859722  100.704167
# 21                           4  13.730278  100.509722
# 22                           3  13.708056  100.583889
# 23                           2  13.887500  100.578889
# 24                           6  13.722317  100.759669
# 25                           2  13.803611  100.607500
# 26                           2  13.813889  100.748056
# 27                           8  13.855556  100.862500
# 28                           2  13.704722  100.348889
# 29                           4  13.744942  100.522200
# 30                           7  13.714722  100.437222
# 31                           2  13.780000  100.542778
# 32                           2  13.702222  100.601667
# 33                          12  13.764444  100.499167
# 34                           5  13.758056  100.513056
# 35                           3  13.716944  100.694444
# 36                           2  13.682222  100.505556
# 37                           4  13.758889  100.534444
# 38                           3  13.919167  100.645833
# 39                           3  13.731389  100.514167
# 40                           3  13.770000  100.684722
# 41                           3  13.708056  100.526389
# 42                           3  13.730278  100.651389
# 43                           6  13.776944  100.456667
# 44                           2  13.787800  100.363800
# 45                           7  13.725000  100.485833
# 46                           2  13.647200  100.495800
# 47                           4  13.786400  100.608700
# 48                           3  13.742222  100.585833
# 49                           2  13.696944  100.543056

# %%
#Transform to Dataframe
df = dfs[0]

# %%
#Fix spelling of the columns
df = df.rename(columns={"Popu-lation": "Population"})
df = df.rename(columns={"District(Khet)": "District"})
df = df.rename(columns={"Post-code": "Postcode"})

# %%
#Clean table 
BKK_districts = df[['District','Postcode','Population','Latitude', 'Longitude']]

# %%
#check if everything is ok
BKK_districts.head()
# Out:
#         District  Postcode  Population   Latitude   Longitude
# 0       Bang Bon     10150      105161  13.659200  100.399100
# 1      Bang Kapi     10240      148465  13.765833  100.647778
# 2      Bang Khae     10160      191781  13.696111  100.409444
# 3      Bang Khen     10220      189539  13.873889  100.596389
# 4  Bang Kho Laem     10120       94956  13.693333  100.502500

# %%
#create an istrogram 
clr = "blue"
BKK_districts.groupby('District')['Population'].sum().plot.bar(figsize=(10,5), color=clr)
plt.title('Population  per District', fontsize = 20)
plt.xlabel('District', fontsize = 15)
plt.ylabel('Population',fontsize = 15)
plt.legend()
plt.show()

# %%
#extract the first district to be use in a test 
df.loc[0, 'District']
# Out:
# 'Bang Bon'

# %%
#test if you can extract Lat and Long
neighborhood_latitude = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'District'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Bang Bon are 13.6592, 100.3991.

# %%
#extract the data from Foursquare 
LIMIT = 500

radius = 1000

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=V1JP0OQNXOSW0TMHAKMEP33U1UAWHCO2I3LZQLTI1MEA1D2Y&client_secret=Y2YU3WT2HRVMRR5H2RPXM3BOW5XMYDN3EIAO2A0MMHW0SEDN&v=20180605&ll=13.6592,100.3991&radius=1000&limit=500'

# %%
#define the main functions used later

def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude


def get_venues(lat,lng):
    #set variables
    radius=1000
    LIMIT=500
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
# prepare neighborhood list that contains Italian restaurants

column_names=['District', 'ID','Name']
ita_rest_bkk=pd.DataFrame(columns=column_names)
count=1
for row in BKK_districts.values.tolist():
    District, Postcode, Population, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    italian_restaurants=venues[venues['Category']=='Italian Restaurant']   
    print('(',count,'/',len(BKK_districts),')','Italian Restaurant in '+District+':'+str(len(italian_restaurants)))
    print(row)
    for resturant_detail in italian_restaurants.values.tolist():
        id, name , category=resturant_detail
        ita_rest_bkk = ita_rest_bkk.append({'District': District,
                                                 'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 50 ) Italian Restaurant in Bang Bon:0
# ['Bang Bon', 10150, 105161, 13.6592, 100.3991]
# ( 2 / 50 ) Italian Restaurant in Bang Kapi:0
# ['Bang Kapi', 10240, 148465, 13.765832999999999, 100.647778]
# ( 3 / 50 ) Italian Restaurant in Bang Khae:0
# ['Bang Khae', 10160, 191781, 13.696110999999998, 100.409444]
# ( 4 / 50 ) Italian Restaurant in Bang Khen:0
# ['Bang Khen', 10220, 189539, 13.873889000000002, 100.596389]
# ( 5 / 50 ) Italian Restaurant in Bang Kho Laem:1
# ['Bang Kho Laem', 10120, 94956, 13.693332999999999, 100.5025]
# ( 6 / 50 ) Italian Restaurant in Bang Khun Thian:0
# ['Bang Khun Thian', 10150, 165491, 13.660832999999998, 100.435833]
# ( 7 / 50 ) Italian Restaurant in Bang Na:0
# ['Bang Na', 10260, 95912, 13.680081, 100.5918]
# ( 8 / 50 ) Italian Restaurant in Bang Phlat:0
# ['Bang Phlat', 10700, 99273, 13.793889000000002, 100.505]
# ( 9 / 50 ) Italian Restaurant in Bang Rak:0
# ['Bang Rak', 10500, 45875, 13.730832999999999, 100.524167]
# ( 10 / 50 ) Italian Restaurant in Bang Sue:0
# ['Bang Sue', 10800, 132234, 13.809722, 100.537222]
# ( 11 / 50 ) Italian Restaurant in Bangkok Noi:0
# ['Bangkok Noi', 10700, 117793, 13.770867, 100.467933]
# ( 12 / 50 ) Italian Restaurant in Bangkok Yai:0
# ['Bangkok Yai', 10600, 72321, 13.722778, 100.476389]
# ( 13 / 50 ) Italian Restaurant in Bueng Kum:0
# ['Bueng Kum', 10240, 145830, 13.785278, 100.669167]
# ( 14 / 50 ) Italian Restaurant in Chatuchak:0
# ['Chatuchak', 10900, 160906, 13.828610999999999, 100.559722]
# ( 15 / 50 ) Italian Restaurant in Chom Thong:0
# ['Chom Thong', 10150, 158005, 13.677222, 100.48472199999999]
# ( 16 / 50 ) Italian Restaurant in Din Daeng:0
# ['Din Daeng', 10400, 130220, 13.769722, 100.552778]
# ( 17 / 50 ) Italian Restaurant in Don Mueang:0
# ['Don Mueang', 10210, 166261, 13.913610999999998, 100.589722]
# ( 18 / 50 ) Italian Restaurant in Dusit:2
# ['Dusit', 10300, 107655, 13.776944, 100.520556]
# ( 19 / 50 ) Italian Restaurant in Huai Khwang:0
# ['Huai Khwang', 10310, 78175, 13.776667000000002, 100.579444]
# ( 20 / 50 ) Italian Restaurant in Khan Na Yao:0
# ['Khan Na Yao', 10230, 88678, 13.8271, 100.6743]
# ( 21 / 50 ) Italian Restaurant in Khlong Sam Wa:0
# ['Khlong Sam Wa', 10510, 169489, 13.859722, 100.704167]
# ( 22 / 50 ) Italian Restaurant in Khlong San:1
# ['Khlong San', 10600, 76446, 13.730278, 100.509722]
# ( 23 / 50 ) Italian Restaurant in Khlong Toei:0
# ['Khlong Toei', 10110, 109041, 13.708056, 100.583889]
# ( 24 / 50 ) Italian Restaurant in Lak Si:0
# ['Lak Si', 10210, 109770, 13.8875, 100.578889]
# ( 25 / 50 ) Italian Restaurant in Lat Krabang:0
# ['Lat Krabang', 10520, 163175, 13.722317000000002, 100.75966899999999]
# ( 26 / 50 ) Italian Restaurant in Lat Phrao:0
# ['Lat Phrao', 10230, 122182, 13.803610999999998, 100.6075]
# ( 27 / 50 ) Italian Restaurant in Min Buri:0
# ['Min Buri', 10510, 137251, 13.813889000000001, 100.748056]
# ( 28 / 50 ) Italian Restaurant in Nong Chok:0
# ['Nong Chok', 10530, 157138, 13.855556, 100.8625]
# ( 29 / 50 ) Italian Restaurant in Nong Khaem:0
# ['Nong Khaem', 10160, 150218, 13.704722, 100.348889]
# ( 30 / 50 ) Italian Restaurant in Pathum Wan:0
# ['Pathum Wan', 10330, 53263, 13.744942000000002, 100.5222]
# ( 31 / 50 ) Italian Restaurant in Phasi Charoen:0
# ['Phasi Charoen', 10160, 129827, 13.714722, 100.43722199999999]
# ( 32 / 50 ) Italian Restaurant in Phaya Thai:1
# ['Phaya Thai', 10400, 72952, 13.78, 100.542778]
# ( 33 / 50 ) Italian Restaurant in Phra Khanong:3
# ['Phra Khanong', 10260, 93482, 13.702222, 100.601667]
# ( 34 / 50 ) Italian Restaurant in Phra Nakhon:2
# ['Phra Nakhon', 10200, 57876, 13.764444000000001, 100.499167]
# ( 35 / 50 ) Italian Restaurant in Pom Prap Sattru Phai:1
# ['Pom Prap Sattru Phai', 10100, 51006, 13.758056, 100.513056]
# ( 36 / 50 ) Italian Restaurant in Prawet:0
# ['Prawet', 10250, 160671, 13.716944, 100.69444399999999]
# ( 37 / 50 ) Italian Restaurant in Rat Burana:1
# ['Rat Burana', 10140, 86695, 13.682222, 100.505556]
# ( 38 / 50 ) Italian Restaurant in Ratchathewi:1
# ['Ratchathewi', 10400, 73035, 13.758889000000002, 100.534444]
# ( 39 / 50 ) Italian Restaurant in Sai Mai:0
# ['Sai Mai', 10220, 188123, 13.919167000000002, 100.645833]
# ( 40 / 50 ) Italian Restaurant in Samphanthawong:1
# ['Samphanthawong', 10100, 27452, 13.731389000000002, 100.514167]
# ( 41 / 50 ) Italian Restaurant in Saphan Sung:0
# ['Saphan Sung', 10240, 89825, 13.77, 100.684722]
# ( 42 / 50 ) Italian Restaurant in Sathon:0
# ['Sathon', 10120, 84916, 13.708056, 100.526389]
# ( 43 / 50 ) Italian Restaurant in Suan Luang:1
# ['Suan Luang', 10250, 115658, 13.730278, 100.651389]
# ( 44 / 50 ) Italian Restaurant in Taling Chan:0
# ['Taling Chan', 10170, 106604, 13.776944, 100.45666700000001]
# ( 45 / 50 ) Italian Restaurant in Thawi Watthana:0
# ['Thawi Watthana', 10170, 76351, 13.7878, 100.3638]
# ( 46 / 50 ) Italian Restaurant in Thon Buri:0
# ['Thon Buri', 10600, 119708, 13.725, 100.485833]
# ( 47 / 50 ) Italian Restaurant in Thung Khru:0
# ['Thung Khru', 10140, 116473, 13.6472, 100.4958]
# ( 48 / 50 ) Italian Restaurant in Wang Thonglang:0
# ['Wang Thonglang', 10310, 114768, 13.7864, 100.6087]
# ( 49 / 50 ) Italian Restaurant in Watthana:2
# ['Watthana', 10110, 81623, 13.742222, 100.585833]
# ( 50 / 50 ) Italian Restaurant in Yan Nawa:0
# ['Yan Nawa', 10120, 81521, 13.696944, 100.543056]

# %%
#make a back-up in .csv file 
ita_rest_bkk.to_csv('ita_rest_bkk_tocsv1.csv')

# %%
#check data
ita_bkk = pd.read_csv('ita_rest_bkk_tocsv1.csv')
ita_rest_bkk.tail()
# Out:
#           District                        ID                        Name
# 12     Ratchathewi  4b46b7f7f964a520542726e3                   Primavera
# 13  Samphanthawong  4e3a8d61a809ec55443c9e3c       Viva & Aviv The River
# 14      Suan Luang  536f66ca498e4c73691a56b9  Sireena Italian Restaurant
# 15        Watthana  4f76e9cbe4b0e91fa6623296                    Sole Mio
# 16        Watthana  526cc2c6498ea29948f9ce08      50/50 Restaurant & Bar

# %%
#check the data size
ita_rest_bkk.shape
# Out:
# (17, 3)

# %%
#Let's Visualize the distribution of the Italian Restaurants
ita_rest_bkk.groupby('District')['ID'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Italian Restaurants per District', fontsize = 20)
plt.xlabel('District', fontsize = 15)
plt.ylabel('Italian Restaurants',fontsize = 15)
plt.legend()
plt.show()

# %%
column_names=['District', 'ID','Name','Likes','Rating','Tips']
ita_rest_stats_bkk=pd.DataFrame(columns=column_names)
count=1
for row in ita_rest_bkk.values.tolist():
    Disrict, ID, Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(ita_rest_bkk),')','processed')
    ita_rest_stats_bkk = ita_rest_stats_bkk.append({'Disrict': Disrict,
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
ita_rest_stats_bkk.head()
# Out:
# {'meta': {'code': 200, 'requestId': '5fcc94e61d3072684733aa6c'}, 'response': {'venue': {'id': '4db5437b0cb6729b6aa17a41', 'name': 'Harbour View', 'contact': {}, 'location': {'address': 'Montien Riverside Hotel', 'lat': 13.687815606440395, 'lng': 100.50808363694624, 'labeledLatLngs': [{'label': 'display', 'lat': 13.687815606440395, 'lng': 100.50808363694624}], 'cc': 'TH', 'city': 'บางโคล่', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['Montien Riverside Hotel', 'บางโคล่', 'กรุงเทพมหานคร', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/harbour-view/4db5437b0cb6729b6aa17a41', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 0}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 3, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 3, 'items': [{'id': '50d3ef5be4b096a1cd20fb0e', 'createdAt': 1356066651, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/7179358_1LZiae9qjbVNKaif3L-V94jp6Bj-3XY-wuyIYibmpBI.jpg', 'width': 540, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Joy', 'lastName': 'C', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1303724923, 'tips': {'count': 0, 'groups': []}, 'shortUrl': 'http://4sq.com/dSq1SG', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'seasonalHours': [], 'pageUpdates': {'count': 0, 'items': []}, 'inbox': {'count': 0, 'items': []}, 'parent': {'id': '4cb11d7c1463a143761da3a9', 'name': 'Montien Riverside Hotel (โรงแรมมณเฑียร ริเวอร์ไซด์)', 'location': {'address': '372 Rama III Rd.', 'lat': 13.68848178083558, 'lng': 100.50786976175873, 'labeledLatLngs': [{'label': 'display', 'lat': 13.68848178083558, 'lng': 100.50786976175873}], 'postalCode': '10120', 'cc': 'TH', 'city': 'บางคอแหลม', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['372 Rama III Rd.', 'บางคอแหลม', 'กรุงเทพมหานคร 10120', 'ประเทศไทย']}, 'categories': [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]}, 'hierarchy': [{'name': 'Montien Riverside Hotel', 'lang': 'en', 'id': '4cb11d7c1463a143761da3a9', 'canonicalUrl': 'https://foursquare.com/v/montien-riverside-hotel-%E0%B9%82%E0%B8%A3%E0%B8%87%E0%B9%81%E0%B8%A3%E0%B8%A1%E0%B8%A1%E0%B8%93%E0%B9%80%E0%B8%91%E0%B8%A2%E0%B8%A3-%E0%B8%A3%E0%B9%80%E0%B8%A7%E0%B8%AD%E0%B8%A3%E0%B9%84%E0%B8%8B%E0%B8%94/4cb11d7c1463a143761da3a9'}], 'attributes': {'groups': [{'type': 'price', 'name': 'Price', 'summary': '฿฿฿', 'count': 1, 'items': [{'displayName': 'Price', 'displayValue': '฿฿฿', 'priceTier': 3}]}]}, 'bestPhoto': {'id': '50d3ef5be4b096a1cd20fb0e', 'createdAt': 1356066651, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/7179358_1LZiae9qjbVNKaif3L-V94jp6Bj-3XY-wuyIYibmpBI.jpg', 'width': 540, 'height': 720, 'visibility': 'public'}, 'colors': {'highlightColor': {'photoId': '50d3ef5be4b096a1cd20fb0e', 'value': -15200240}, 'highlightTextColor': {'photoId': '50d3ef5be4b096a1cd20fb0e', 'value': -1}, 'algoVersion': 3}}}}
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4db5437b0cb6729b6aa17a41
# ( 1 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e65b23bb23307f2346'}, 'response': {'venue': {'id': '4d4250008b88b1f70039ea33', 'name': 'Volcano (โวลคาโน)', 'contact': {'phone': '+6622436237', 'formattedPhone': '+66 2 243 6237'}, 'location': {'address': '406 Sawankhalok Rd.', 'crossStreet': 'at Sukhothai Mansion', 'lat': 13.773467715172131, 'lng': 100.52671110381156, 'labeledLatLngs': [{'label': 'display', 'lat': 13.773467715172131, 'lng': 100.52671110381156}], 'postalCode': '10300', 'cc': 'TH', 'city': 'ดุสิต', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['406 Sawankhalok Rd. (at Sukhothai Mansion)', 'ดุสิต', 'กรุงเทพมหานคร 10300', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/volcano-%E0%B9%82%E0%B8%A7%E0%B8%A5%E0%B8%84%E0%B8%B2%E0%B9%82%E0%B8%99/4d4250008b88b1f70039ea33', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 18}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 26, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 67, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 67, 'items': [{'id': '5f05bc2142ba4b62a7ce81d8', 'createdAt': 1594211361, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/43345281_1nKqME61IJ-q8d0pWUQX15i7P9Agvdf88LlyCB81V3c.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Liftildapeak', 'lastName': 'W', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1296191488, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '4ed5d2e20e61cbb939160535', 'createdAt': 1322636002, 'text': 'Spaghetti Salad is very delicious! Try also Spaghetti Black pepper with Beef and Saffron Risotto ;) very yummy.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4ed5d2e20e61cbb939160535', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': '@raiw@', 'lastName': 'N', 'countryCode': 'TH'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Tiggy', 'lastName': 'T', 'countryCode': 'MM'}}]}]}, 'shortUrl': 'http://4sq.com/huC0Xe', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 6, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 6, 'items': [{'id': '51ac3378498e83fcf282f248', 'name': 'Ari', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Foung', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/30375535/list/ari', 'canonicalUrl': 'https://foursquare.com/user/30375535/list/ari', 'createdAt': 1370239864, 'updatedAt': 1424061537, 'followers': {'count': 0}, 'listItems': {'count': 21, 'items': [{'id': 'v4d4250008b88b1f70039ea33', 'createdAt': 1397735180}]}}, {'id': '5734ff3a498eb9d7a7fbcdd1', 'name': 'Bangkok', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Naphat', 'lastName': 'K', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': True, 'url': '/naphat/list/bangkok', 'canonicalUrl': 'https://foursquare.com/naphat/list/bangkok', 'createdAt': 1463091002, 'updatedAt': 1523957917, 'photo': {'id': '51e26c8 ...
#                          ID               Name  Likes  Rating  Tips
# 0  4d4250008b88b1f70039ea33  Volcano (โวลคาโน)     12     7.5    18
# ( 2 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e6aae4a50da4766c42'}, 'response': {'venue': {'id': '4c0e4460b1b676b039bde186', 'name': 'Platform 1 (แพลตฟอร์ม วัน)', 'contact': {}, 'location': {'address': 'Soi Ronnachai', 'crossStreet': 'Thanon Kampaengpetch 5', 'lat': 13.777738105295846, 'lng': 100.52962646658675, 'labeledLatLngs': [{'label': 'display', 'lat': 13.777738105295846, 'lng': 100.52962646658675}], 'postalCode': '10400', 'cc': 'TH', 'city': 'พญาไท', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['Soi Ronnachai (Thanon Kampaengpetch 5)', 'พญาไท', 'กรุงเทพมหานคร 10400', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/platform-1-%E0%B9%81%E0%B8%9E%E0%B8%A5%E0%B8%95%E0%B8%9F%E0%B8%AD%E0%B8%A3%E0%B8%A1-%E0%B8%A7%E0%B8%99/4c0e4460b1b676b039bde186', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 15}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 20, 'groups': [{'type': 'others', 'count': 20, 'items': []}], 'summary': '20 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.1, 'ratingColor': 'C5DE35', 'ratingSignals': 31, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 125, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 125, 'items': [{'id': '5f88422f2843fe377f291394', 'createdAt': 1602765359, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/28027129_qksWt4VLDniT6GYR63Xk2sMcYTfk5csU4kXhTx-r9dw.jpg', 'width': 1080, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Bay', 'lastName': 'V', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1276003424, 'tips': {'count': 15, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 15, 'items': [{'id': '4b7aa9aa70c603bb986092b4', 'createdAt': 1266330026, 'text': 'อาหารอร่อย บรรยากาศดีมากครับ', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4b7aa9aa70c603bb986092b4', 'lang': 'th', 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': []}], 'summary': '5 likes'}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'BlckZheeP', 'countryCode': 'TH'}}]}]}, 'shortUrl': 'http://4sq.com/avfjc5', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 9, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 9, 'items': [{'id': '51fcd7d6498ec3168a4aee70', 'name': 'Restaurant', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Bhurinut', 'lastName': 'C', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/porparnc/list/restaurant', 'canonicalUrl': 'https://foursquare.com/porparnc/list/restaurant', 'createdAt': 1375524822, 'updatedAt': 1490834078, 'followers': {'count': 1}, 'listItems': {'count': 134, 'items': [{'id': 'v4c0e4460b1b676b039bde186', 'createdAt': 1406902165}]}}, {'id': '4ec34aa293ad2f88386f27ef', 'name': 'My Favorite Restaurants', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Tique', 'lastName': 'V', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/venedica2009/list/my-favorite-restaurants', 'canonicalUrl': 'https://foursquare.com/venedica2009/list/my-favorite-restaurants', 'createdAt': 1321421474, 'updatedAt': 1398555822, 'followers': {'count': 1}, 'listItems': {'count': 46, 'items': [{'id': 't4ed3897a7ee5be844eca2e01', 'createdAt': 1322486195}]}}, {'id': '500fa18 ...
#                          ID                        Name  Likes  Rating  Tips
# 0  4c0e4460b1b676b039bde186  Platform 1 (แพลตฟอร์ม วัน)     20     7.1    15
# ( 3 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e79854b71efb5d4e6b'}, 'response': {'venue': {'id': '4e3a8d61a809ec55443c9e3c', 'name': 'Viva & Aviv The River', 'contact': {'phone': '+6626396305', 'formattedPhone': '+66 2 639 6305'}, 'location': {'address': 'River City', 'crossStreet': 'G Fl. Unit 118', 'lat': 13.73018355207672, 'lng': 100.51297463525955, 'labeledLatLngs': [{'label': 'display', 'lat': 13.73018355207672, 'lng': 100.51297463525955}], 'postalCode': '10100', 'cc': 'TH', 'city': 'สัมพันธวงศ์', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['River City (G Fl. Unit 118)', 'สัมพันธวงศ์', 'กรุงเทพมหานคร 10100', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/viva--aviv-the-river/4e3a8d61a809ec55443c9e3c', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 37}, 'url': 'http://www.vivaaviv.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 89, 'groups': [{'type': 'others', 'count': 89, 'items': []}], 'summary': '89 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 142, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 447, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 447, 'items': [{'id': '51da9a5d498e35851ad6fa6d', 'createdAt': 1373280861, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4590668_K5gYqWH_cZtJRYYE98RSMXi7HRglpPW4MOfn_O8xwMA.jpg', 'width': 720, 'height': 960, 'user': {'isSanctioned': False, 'firstName': '\ue304J̤̈ṳ̈S̤̈T̤̈J̤̈ï̤B̤̈J̤̈ï̤B̤̈\ue437', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1312460129, 'tips': {'count': 37, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 37, 'items': [{'id': '4e74ce4b1495be5170d44b09', 'createdAt': 1316277835, 'text': 'outdoor zone, pls!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4e74ce4b1495be5170d44b09', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'isSanctioned': False, 'firstName': 'Maro', 'lastName': 'S', 'countryCode': 'HR'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'isSanctioned': False, 'firstName': 'Poon', 'lastName': 'S', 'countryCode': 'TH'}}]}]}, 'shortUrl': 'http://4sq.com/nTqH1Q', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 53, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 53, 'items': [{'id': '5016df42e4b021abb088ffb8', 'name': 'Bangkok Bars & Clubs', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'K', 'lastName': 'O', 'countryCode': 'SG'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/32332694/list/bangkok-bars--clubs', 'canonicalUrl': 'https://foursquare.com/user/32332694/list/bangkok-bars--clubs', 'createdAt': 1343676226, 'updatedAt': 1419809384, 'photo': {'id': '4fd61e99121dc5ba009280f8', 'createdAt': 1339432601, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/gfQFSPDbC6WcyKihQGRshrRB5897pXRvGtQ8WAgzmEs.jpg', 'width': 912, 'height': 684, 'user': {'isSanctioned': False, 'firstName': 'Emi ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4e3a8d61a809ec55443c9e3c  Viva & Aviv The River     89     7.6    37
# ( 4 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e7b1c42f0105743b45'}, 'response': {'venue': {'id': '57ebdb93498e32e2e0d4662f', 'name': 'Cantina Wine Bar & Restaurant', 'contact': {}, 'location': {'address': 'Soi Ari Samphan 3', 'lat': 13.778508830699058, 'lng': 100.53866887328566, 'labeledLatLngs': [{'label': 'display', 'lat': 13.778508830699058, 'lng': 100.53866887328566}], 'postalCode': '10400', 'cc': 'TH', 'city': 'พญาไท', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['Soi Ari Samphan 3', 'พญาไท', 'กรุงเทพมหานคร 10400', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/cantina-wine-bar--restaurant/57ebdb93498e32e2e0d4662f', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 9}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 27, 'groups': [{'type': 'others', 'count': 27, 'items': []}], 'summary': '27 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.9, 'ratingColor': 'C5DE35', 'ratingSignals': 41, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 61, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 61, 'items': [{'id': '5fc79a70a00dec5f2541032c', 'createdAt': 1606916720, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1770026_8eMIbxP7TymtV5Y0-_4yLC8ZUs2-pDi07nwxXxPz_KA.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Pang', 'lastName': 'L', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1475074963, 'tips': {'count': 9, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 9, 'items': [{'id': '5b45a3cda87921002cebdfd8', 'createdAt': 1531290573, 'text': 'Lovely place to eat and enjoy Italian food.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5b45a3cda87921002cebdfd8', 'photo': {'id': '5b45a3d067af3a002c35c0b2', 'createdAt': 1531290576, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/12658742_5uHDyJd-_Mh28C20RwlYlBfBkwfQIMBtcwEB1iJBOdE.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/12658742_5uHDyJd-_Mh28C20RwlYlBfBkwfQIMBtcwEB1iJBOdE.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Torzin S', 'countryCode': 'TH'}, 'authorInteractionType': 'meh'}]}]}, 'shortUrl': 'http://4sq.com/2d9BZF0', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 15, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 15, 'items': [{'id': '58d14b04739d854238552839', 'name': 'New!', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'STARSKI', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/superstarski/list/new', 'canonicalUrl': 'https://foursquare.com/superstarski/list/new', 'createdAt': 1490111236, 'updatedAt': 1525401219, 'followers': {'count': 0}, 'listItems': {'count': 46, 'items': [{'id': 'v57ebdb93498e32e2e0d4662f', 'createdAt': 1501918912}]}}, {'id': '53204199498e0c08f325c2dd', 'name': 'BKK_European Restaurant', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': ': P', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/22203323/list/bkkeuropean-restaurant', 'canonicalUrl': 'https ...
#                          ID                           Name  Likes  Rating  \
# 0  57ebdb93498e32e2e0d4662f  Cantina Wine Bar & Restaurant     27     7.9
#
#    Tips
# 0     9
# ( 5 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e785adf10fc14c49e9'}, 'response': {'venue': {'id': '4d280a8555a8b60cdbd4c9c0', 'name': 'Look-in (ลูกอิน)', 'contact': {'phone': '+6627415242', 'formattedPhone': '+66 2 741 5242'}, 'location': {'address': '1 Soi Sukhumvit 58', 'lat': 13.700512557506652, 'lng': 100.60298654127538, 'labeledLatLngs': [{'label': 'display', 'lat': 13.700512557506652, 'lng': 100.60298654127538}], 'postalCode': '10260', 'cc': 'TH', 'city': 'พระไขนง', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['1 Soi Sukhumvit 58', 'พระไขนง', 'กรุงเทพมหานคร 10260', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/%E0%B8%A5%E0%B8%81%E0%B8%AD%E0%B8%99-lookin/4d280a8555a8b60cdbd4c9c0', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 28}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 56, 'groups': [{'type': 'others', 'count': 56, 'items': []}], 'summary': '56 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 83, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 199, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 199, 'items': [{'id': '5fa3e76e8afa155918cdd352', 'createdAt': 1604577134, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/8287304_DlOHaVrD20aELjSyA7LK1tXVjx5GX7nFHZaeQupNGPg.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'SiLiCaTE', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1294469765, 'tips': {'count': 28, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 28, 'items': [{'id': '4cdfe46d70bba1cd9f5969c4', 'createdAt': 1289741421, 'text': 'All Italian food is so delicious !!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4cdfe46d70bba1cd9f5969c4', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'isSanctioned': False, 'firstName': 'Banjerd', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'ｐｃｎ', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'NEUNG Thanajittara', 'lastName': 'G', 'countryCode': 'TH'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'NTTNN', 'lastName': 'W', 'countryCode': 'TH'}}]}]}, 'shortUrl': 'http://4sq.com/hor0Ml', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 30, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 30, 'items': [{'id': '4fb27a25e4b0f8eb2a26b44a', 'name': 'Les restaurants', 'description': "i'll die to dine here", 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Fräulein', 'lastName': 'R', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/purplepinklips/list/les-restaurants', 'canonicalUrl': 'https://foursquare.com/purplepinklips/list/les-restaurants', 'createdAt': 1337096741, 'updatedAt': 1427812260, 'photo': {'id': '4e3a9063e4cdcd106842142e', 'createdAt': 1312460899, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/H2DWPB0IG5ZCDU4E32FHXUATHZGK5D2YI1R5IFYJQF0CEC0O.jpg', 'width': 477, 'height': 478, 'user': {'isSanctioned': False, 'firstName': 'Pinku', 'lastName': 'N', 'countryCode': 'TH'}, 'visibility': 'public'}, 'followers': {'count': 16}, 'listItems': {'count': 149, 'items': ...
#                          ID              Name  Likes  Rating  Tips
# 0  4d280a8555a8b60cdbd4c9c0  Look-in (ลูกอิน)     56     8.1    28
# ( 6 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e7f182532cb0863545'}, 'response': {'venue': {'id': '585680a833a24554231bcb5a', 'name': 'Peppe', 'contact': {'phone': '+6627414798', 'formattedPhone': '+66 2 741 4798', 'facebook': '1950284581938290', 'facebookUsername': 'peppebkk76', 'facebookName': 'Peppe Italian Food and Wine'}, 'location': {'address': '1954/3 Sukhumvit 60', 'lat': 13.69892, 'lng': 100.603815, 'labeledLatLngs': [{'label': 'display', 'lat': 13.69892, 'lng': 100.603815}], 'postalCode': '10260', 'cc': 'TH', 'city': 'พระไขนง', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['1954/3 Sukhumvit 60', 'พระไขนง', 'กรุงเทพมหานคร 10260', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/peppe/585680a833a24554231bcb5a', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 5}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 11, 'groups': [{'type': 'others', 'count': 11, 'items': []}], 'summary': '11 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.7, 'ratingColor': '73CF42', 'ratingSignals': 15, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 47, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 47, 'items': [{'id': '5f7732a3816dda1db13b5488', 'createdAt': 1601647267, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5819514_ZP8gpRtkWzNHV6bHkInm_QC7bJTjJibUZu6Ks_-BKRA.jpg', 'width': 1440, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Art', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1482064040, 'tips': {'count': 5, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 5, 'items': [{'id': '5ce94aa18a6f17002ca1c1ae', 'createdAt': 1558792865, 'text': 'Superb fresh fettuccine.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5ce94aa18a6f17002ca1c1ae', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Prapapun', 'lastName': 'Y', 'countryCode': 'TH'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2hwSTzz', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 15, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 15, 'items': [{'id': '53204199498e0c08f325c2dd', 'name': 'BKK_European Restaurant', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': ': P', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/22203323/list/bkkeuropean-restaurant', 'canonicalUrl': 'https://foursquare.com/user/22203323/list/bkkeuropean-restaurant', 'createdAt': 1394622873, 'updatedAt': 1605516105, 'photo': {'id': '4fe6b5bde4b04318c4396285', 'createdAt': 1340519869, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/U_zhqMl23HSQAbKPtX9vu1U8RhMD5FjyE3H3F-x9HHU.jpg', 'width': 473, 'height': 473, 'user': {'isSanctioned': False, 'firstName': 'Pinku', 'lastName': 'N', 'countryCode': 'TH'}, 'visibility': 'public'}, 'followers': {'count': 3}, 'listItems': {'count': 250, 'items': [{'id': 'v585680a833a24554231bcb5a', 'createdAt': 1557330316}]}}, {'id': '5142049ce4b07c04085620f7', 'name': 'BKK Western Cuisines', 'description': 'Great European and American restaurants in Bangkok.', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Kamol', 'lastName': 'C', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'coll ...
#                          ID   Name  Likes  Rating  Tips
# 0  585680a833a24554231bcb5a  Peppe     11     8.7     5
# ( 7 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e7a788655b3ed05b5b'}, 'response': {'venue': {'id': '510a6a16e4b0ee134488dab9', 'name': 'Cabana Garden', 'contact': {'phone': '+6627426405', 'formattedPhone': '+66 2 742 6405', 'facebook': '574327642710958', 'facebookUsername': 'cabanagardenrestaurant', 'facebookName': 'Cabana garden'}, 'location': {'address': '2 Sukhumvit 75/1', 'lat': 13.709911571904664, 'lng': 100.5998366534986, 'labeledLatLngs': [{'label': 'display', 'lat': 13.709911571904664, 'lng': 100.5998366534986}], 'postalCode': '10110', 'cc': 'TH', 'neighborhood': 'Vadhana', 'city': 'วัฒนา', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['2 Sukhumvit 75/1', 'วัฒนา', 'กรุงเทพมหานคร 10110', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/cabana-garden/510a6a16e4b0ee134488dab9', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 6}, 'url': 'http://cabanagarden.co', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 24, 'groups': [{'type': 'others', 'count': 24, 'items': []}], 'summary': '24 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 33, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 19, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 19, 'items': [{'id': '5ebf4fb34433520008ece6d6', 'createdAt': 1589596083, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/8287304_dOUbKkQqbeynmHw-T4dU0SKzTJiSTaSQDLdlGhbwZXw.jpg', 'width': 1440, 'height': 1599, 'user': {'isSanctioned': False, 'firstName': 'SiLiCaTE', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1359637014, 'tips': {'count': 6, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 6, 'items': [{'id': '58c4d7299900e67bac289db0', 'createdAt': 1489295145, 'text': 'Very quiet and friendly. Owner is French, so there are always good selection of wine and pizza is quite good... for French... you know :)', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/58c4d7299900e67bac289db0', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Pavel', 'lastName': 'S', 'countryCode': 'TH'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/VxnTQl', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 11, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 11, 'items': [{'id': '57aeef5b498e0350e566b96c', 'name': 'Asoke Sukhumvit', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Kotchsak', 'lastName': 'S', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/153388156/list/asoke-sukhumvit', 'canonicalUrl': 'https://foursquare.com/user/153388156/list/asoke-sukhumvit', 'createdAt': 1471082331, 'updatedAt': 1527060714, 'photo': {'id': '5794657c498ea410bf2c59fc', 'createdAt': 1469343100, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1396971_aJKBFyKc-eiI9ZX3QlZZovWDh9vpCwZoUi9_l84oqGY.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Candi', 'lastName': 'P', 'countryCode': 'TH'}, 'visibility': 'public'}, 'followers': {'count': 0}, 'listItems': {'count': 18, 'items': [{'id': 'v510a6a16e4b0ee134488dab9', 'createdAt': 1524729184}]}}, {'id': '598f4dd5e57ca6134519648d', 'name': 'To Try', 'description': '', 'type': 'others ...
#                          ID           Name  Likes  Rating  Tips
# 0  510a6a16e4b0ee134488dab9  Cabana Garden     24     8.2     6
# ( 8 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e882244217e630e0a0'}, 'response': {'venue': {'id': '527f77ae11d251578b0656c6', 'name': 'Delicatezza', 'contact': {'phone': '+6626295775', 'formattedPhone': '+66 2 629 5775', 'facebook': '174000039457000', 'facebookName': 'Delicatezza Baan Phra-Arthit'}, 'location': {'address': '102/1 Phra Athit Rd.', 'lat': 13.762974385564123, 'lng': 100.49467060772032, 'labeledLatLngs': [{'label': 'display', 'lat': 13.762974385564123, 'lng': 100.49467060772032}], 'postalCode': '10200', 'cc': 'TH', 'city': 'พระนคร', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['102/1 Phra Athit Rd.', 'พระนคร', 'กรุงเทพมหานคร 10200', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/delicatezza/527f77ae11d251578b0656c6', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 10}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 17, 'groups': [{'type': 'others', 'count': 17, 'items': []}], 'summary': '17 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 26, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 73, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 73, 'items': [{'id': '5fcb83d35d0373348303a5f4', 'createdAt': 1607173075, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/6357921_WKiiCCI0yftBpEj_x3DAvAsQnHp8k50NTG4zqIyn7c8.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Chinaphong', 'lastName': 'K', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'Delicatezza premium home-made Italian food by Zariya Paula since 1999. \nInspire your finest life, why not "Delicatezza"', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1384085422, 'tips': {'count': 10, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 10, 'items': [{'id': '532040a711d289a2e5c889b4', 'createdAt': 1394622631, 'text': 'Recommended seafood soup in tomato sauce. So spicy and tasty. Must tr', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/532040a711d289a2e5c889b4', 'photo': {'id': '532040aa498e2aa6ce15ec0f', 'createdAt': 1394622634, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5488929_nsMAi049VrwnVHHJd7BoR_Th2kkp2rsrZ3BtSyfWmhA.jpg', 'width': 720, 'height': 960, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/5488929_nsMAi049VrwnVHHJd7BoR_Th2kkp2rsrZ3BtSyfWmhA.jpg', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Pla', 'lastName': 'R', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Pachana', 'lastName': 'R', 'countryCode': 'KH'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Pachana', 'lastName': 'R', 'countryCode': 'KH'}}]}]}, 'shortUrl': 'http://4sq.com/17MguDk', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 16, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 16, 'items': [{'id': '53204199498e0c08f325c2dd', 'name': 'BKK_European Restaurant', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': ': P', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/22203323/list/bkkeuropean-restaurant', 'canonicalUrl': 'https://f ...
#                          ID         Name  Likes  Rating  Tips
# 0  527f77ae11d251578b0656c6  Delicatezza     17     8.0    10
# ( 9 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e8a788655b3ed05c8b'}, 'response': {'venue': {'id': '4d6e3d17fbb8a1cdeabc700f', 'name': "Ranee's Velo Restaurant (รานีส์เวโล เรสเตอรองต์)", 'contact': {}, 'location': {'address': 'Trok Mayom', 'lat': 13.75882720550754, 'lng': 100.49575489762624, 'labeledLatLngs': [{'label': 'display', 'lat': 13.75882720550754, 'lng': 100.49575489762624}], 'postalCode': '10200', 'cc': 'TH', 'city': 'พระนคร', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['Trok Mayom', 'พระนคร', 'กรุงเทพมหานคร 10200', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/ranees-velo-restaurant-%E0%B8%A3%E0%B8%B2%E0%B8%99%E0%B8%AA%E0%B9%80%E0%B8%A7%E0%B9%82%E0%B8%A5-%E0%B9%80%E0%B8%A3%E0%B8%AA%E0%B9%80%E0%B8%95%E0%B8%AD%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B8%95/4d6e3d17fbb8a1cdeabc700f', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 19}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 20, 'groups': [{'type': 'others', 'count': 20, 'items': []}], 'summary': '20 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 38, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 80, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 80, 'items': [{'id': '50489eb3e4b00f91b9d201a2', 'createdAt': 1346936499, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Ui8-za9vJjFZr_TZN6mMO1BN42WHSbNZ-W67qSYdxVI.jpg', 'width': 720, 'height': 540, 'user': {'isSanctioned': False, 'firstName': 'Elena', 'lastName': 'R', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 1, 'summary': 'One other person is here', 'groups': [{'type': 'others', 'name': 'Other people here', 'count': 1, 'items': []}]}, 'createdAt': 1299070231, 'tips': {'count': 19, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 19, 'items': [{'id': '5233345111d2d6b3221f2509', 'createdAt': 1379087441, 'text': 'The pizzas are all fresh made in the wooden oven. Great taste! Come and try it!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5233345111d2d6b3221f2509', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Thanapat', 'lastName': 'S', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Tanach', 'lastName': 'B', 'countryCode': 'TH'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Angelica', 'lastName': 'W', 'countryCode': 'TH'}}]}]}, 'shortUrl': 'http://4sq.com/eMtVlJ', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 11, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 11, 'items': [{'id': '53204199498e0c08f325c2dd', 'name': 'BKK_European Restaurant', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': ': P', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/22203323/list/bkkeuropean-restaurant', 'canonicalUrl': 'https://foursquare.com/user/22203323/list/bkkeuropean-restaurant', 'createdAt': 1394622873, 'updatedAt': 1605516105, 'photo': {'id': '4fe6b5bde4b04318c4396285', 'createdAt': 1340519869, 'prefix': 'https://fastly.4sqi.net/img/general/' ...
#                          ID                                              Name  \
# 0  4d6e3d17fbb8a1cdeabc700f  Ranee's Velo Restaurant (รานีส์เวโล เรสเตอรองต์)
#
#    Likes  Rating  Tips
# 0     20     8.2    19
# ( 10 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e82aa0530e5abde7b4'}, 'response': {'venue': {'id': '54f083fd498ec4bc812a78ae', 'name': 'Ja Kin Ya Bon (จะกินอย่าบ่น)', 'contact': {'phone': '+6622824003', 'formattedPhone': '+66 2 282 4003', 'facebook': '767114346706302', 'facebookUsername': 'jakinyabon', 'facebookName': 'Ja Kin Ya Bon Cuisine & Bar'}, 'location': {'address': '554/1-2 Phra Sumen Rd', 'lat': 13.757115142878364, 'lng': 100.50448565512374, 'labeledLatLngs': [{'label': 'display', 'lat': 13.757115142878364, 'lng': 100.50448565512374}], 'postalCode': '10200', 'cc': 'TH', 'city': 'พระนคร', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['554/1-2 Phra Sumen Rd', 'พระนคร', 'กรุงเทพมหานคร 10200', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/%E0%B8%88%E0%B8%B0%E0%B8%81%E0%B8%99%E0%B8%AD%E0%B8%A2%E0%B8%B2%E0%B8%9A%E0%B8%99-ja-kin-ya-bon/54f083fd498ec4bc812a78ae', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'url': 'http://www.jakinyabon.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'isSanctioned': False, 'firstName': 'Maem-Pemika', 'lastName': 'C', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Alex', 'lastName': 'G', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'NattDee', 'lastName': 'T', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'natscracker', 'lastName': 'c', 'countryCode': 'TH'}]}], 'summary': '7 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.2, 'ratingColor': 'C5DE35', 'ratingSignals': 8, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 26, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 26, 'items': [{'id': '5c2a33b118d43b002c90e619', 'createdAt': 1546269617, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1222737_OQHvbEBLCAPqI-kJg5djo8J8ZiySptOMvr8XXN3TwrI.jpg', 'width': 1068, 'height': 1900, 'user': {'isSanctioned': False, 'firstName': 'Maem-Pemika', 'lastName': 'C', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1425048573, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5c2a33ea9b0473002ceba704', 'createdAt': 1546269674, 'text': 'The name is changed to Steve café and cuisine', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c2a33ea9b0473002ceba704', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Maem-Pemika', 'lastName': 'C', 'countryCode': 'TH'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1E3SoSR', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 3, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 3, 'items': [{'id': '51e0d67e498e78be0b5eed89', 'name': 'EAT • PLAY • LOVE', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Fahsai', 'lastName': 'J', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/manifah/list/eat--play--love', 'canonicalUrl': 'https://foursquare.com/manifah/list/eat--play--love', 'createdAt': 1373689470, 'updatedAt': 1583561099, 'photo': {'id': '520f875c11d23848b7e1d2dd', 'createdAt': 1376749404, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/6379185_4QcJHMWcs0DoxnCWxSKStOBw6lwjFzQTUajrVK7GpT4.jpg', 'width ...
#                          ID                          Name  Likes  Rating  Tips
# 0  54f083fd498ec4bc812a78ae  Ja Kin Ya Bon (จะกินอย่าบ่น)      7     7.2     3
# ( 11 / 17 ) processed
# ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4e3a8d61a809ec55443c9e3c  Viva & Aviv The River     89     7.6    37
# ( 14 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e9e915b64c93b9a233'}, 'response': {'venue': {'id': '536f66ca498e4c73691a56b9', 'name': 'Sireena Italian Restaurant', 'contact': {'phone': '+66841158888', 'formattedPhone': '+66 84 115 8888', 'facebook': '712670752137980', 'facebookUsername': 'SireenaRestaurant', 'facebookName': 'Sireena'}, 'location': {'address': '2996 โครงการ The Pattio', 'crossStreet': 'พัฒนาการ', 'lat': 13.731484870166522, 'lng': 100.65059636650425, 'labeledLatLngs': [{'label': 'display', 'lat': 13.731484870166522, 'lng': 100.65059636650425}], 'postalCode': '10250', 'cc': 'TH', 'city': 'พระนคร', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['2996 โครงการ The Pattio (พัฒนาการ)', 'พระนคร', 'กรุงเทพมหานคร 10250', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/sireena-italian-restaurant/536f66ca498e4c73691a56b9', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 8}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'isSanctioned': False, 'firstName': 'Korn', 'lastName': 'G', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Pornrapee', 'lastName': 'A', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Mintty', 'lastName': 'S', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Ruamlarp', 'lastName': 'A', 'countryCode': 'TH'}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 13, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 37, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 37, 'items': [{'id': '5d264e8d53331f002342687a', 'createdAt': 1562791565, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/550419147_Ymfmz6Lf3I10S40QNV0UjxZ1aF266XimaKsZrl9LMKg.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Korn', 'lastName': 'G', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1399809738, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '5597d5e7498ea9b97cc88e79', 'createdAt': 1436014055, 'text': 'Pizzas, pasta all good. Amazing find!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5597d5e7498ea9b97cc88e79', 'photo': {'id': '5597d5ed498eee6746c8aae4', 'createdAt': 1436014061, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5714874_meiJzqOY9lwwCQOa8ZjJIn9zyedFI-UOWqsarUFErAI.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/5714874_meiJzqOY9lwwCQOa8ZjJIn9zyedFI-UOWqsarUFErAI.jpg', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': 'Ruamlarp', 'lastName': 'A', 'countryCode': 'TH'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Kin', 'countryCode': 'TH'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1sAQWim', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 3, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 3, 'items': [{'id': '52635d6a498ee0f0a7cc2b5d', 'name': 'Newly / Never Try', 'description': '', 'type': 'others', 'user': ...
#                          ID                        Name  Likes  Rating  Tips
# 0  536f66ca498e4c73691a56b9  Sireena Italian Restaurant      8     7.6     8
# ( 15 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e924f6880346d5a320'}, 'response': {'venue': {'id': '4f76e9cbe4b0e91fa6623296', 'name': 'Sole Mio', 'contact': {'phone': '+6621852799', 'formattedPhone': '+66 2 185 2799', 'facebook': '168946469883544', 'facebookUsername': 'SOLEMIOBANGKOK', 'facebookName': 'SOLE MIO: Bangkok'}, 'location': {'address': '81 Thong Lo 13', 'lat': 13.736724969987064, 'lng': 100.58318597417431, 'labeledLatLngs': [{'label': 'display', 'lat': 13.736724969987064, 'lng': 100.58318597417431}], 'postalCode': '10110', 'cc': 'TH', 'city': 'วัฒนา', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['81 Thong Lo 13', 'วัฒนา', 'กรุงเทพมหานคร 10110', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/sole-mio/4f76e9cbe4b0e91fa6623296', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 20}, 'url': 'http://www.solemiobkk.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 41, 'groups': [{'type': 'others', 'count': 41, 'items': []}], 'summary': '41 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 66, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 113, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 113, 'items': [{'id': '521357fc11d2a1e2b63a17d7', 'createdAt': 1376999420, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/152864_RQBYYKC_MKArP481YCqdomj2ltJXtbcVH8qeX8WDooo.jpg', 'width': 960, 'height': 719, 'user': {'isSanctioned': False, 'firstName': 'Claudio', 'lastName': 'S', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '33986211'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Genuine Italian Cuisine and Wine.', 'storeId': '', 'page': {'user': {'isSanctioned': False, 'firstName': 'Sole Mio', 'countryCode': 'TH', 'type': 'venuePage', 'venue': {'id': '4f76e9cbe4b0e91fa6623296'}, 'tips': {'count': 1}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1333193163, 'tips': {'count': 20, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 20, 'items': [{'id': '53e3b37f498e8d6a4de41bd2', 'createdAt': 1407431551, 'text': 'All dishes are delicious!...pasta, pizza, risotto, lamb, sole mio salad...very good service...and decent dessert', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/53e3b37f498e8d6a4de41bd2', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': '直之', 'lastName': '古', 'countryCode': 'TH'}, {'isSanctioned': False, 'firstName': 'Oil', 'lastName': 'K', 'countryCode': 'TH'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 2}, 'user': {'isSanctioned': False, 'firstName': 'Art', 'countryCode': 'TH'}}]}]}, 'shortUrl': 'http://4sq.com/H4Q8LJ', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 31, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 31, 'items': [{'id': '4f628934e4b02ac2c34e4769', 'name': 'Restaurants', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'M', 'lastName': 'G', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/23913123/list/restaurants', 'canonicalUrl': 'https://foursquare.com/user/23913123/list/restaurants', 'createdAt': 1331857716, ...
#                          ID      Name  Likes  Rating  Tips
# 0  4f76e9cbe4b0e91fa6623296  Sole Mio     41     8.1    20
# ( 16 / 17 ) processed
# {'meta': {'code': 200, 'requestId': '5fcc94e927dc4e1dbb4eb67a'}, 'response': {'venue': {'id': '526cc2c6498ea29948f9ce08', 'name': '50/50 Restaurant & Bar', 'contact': {'phone': '+66805815050', 'formattedPhone': '+66 80 581 5050', 'facebook': '539710902745141', 'facebookUsername': 'FiftyFiftyRestaurant', 'facebookName': '50/50'}, 'location': {'address': '998 Thong Lo', 'crossStreet': 'H1 Place', 'lat': 13.741575101632048, 'lng': 100.58591401346702, 'labeledLatLngs': [{'label': 'display', 'lat': 13.741575101632048, 'lng': 100.58591401346702}], 'postalCode': '10110', 'cc': 'TH', 'city': 'วัฒนา', 'state': 'กรุงเทพมหานคร', 'country': 'ประเทศไทย', 'formattedAddress': ['998 Thong Lo (H1 Place)', 'วัฒนา', 'กรุงเทพมหานคร 10110', 'ประเทศไทย']}, 'canonicalUrl': 'https://foursquare.com/v/5050-restaurant--bar/526cc2c6498ea29948f9ce08', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '฿'}, 'likes': {'count': 11, 'groups': [{'type': 'others', 'count': 11, 'items': []}], 'summary': '11 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.1, 'ratingColor': 'C5DE35', 'ratingSignals': 15, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 62, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 62, 'items': [{'id': '52c127c7498efb006ca83443', 'createdAt': 1388390343, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/345682_ciy-2aKo13j8b6KWJSLCdq6lXza8YC3WEofh1Hmw6C4.jpg', 'width': 640, 'height': 640, 'user': {'isSanctioned': False, 'firstName': 'PeteZeed', 'countryCode': 'TH'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1382859462, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '527efd75498e8d1d5b4b52d3', 'createdAt': 1384054133, 'text': 'Lovely sweet~', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/527efd75498e8d1d5b4b52d3', 'photo': {'id': '527efd7e11d269e8c34e9bc9', 'createdAt': 1384054142, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2266004_Syc5rc2_BU4KVdxMQfIRR_bGs7WgfY_2XwSHdTlHhgM.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/2266004_Syc5rc2_BU4KVdxMQfIRR_bGs7WgfY_2XwSHdTlHhgM.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Pailin', 'lastName': 'P', 'countryCode': 'TH'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1gRPSUQ', 'timeZone': 'Asia/Bangkok', 'listed': {'count': 15, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 15, 'items': [{'id': '52e3f8ac498e847239f33e06', 'name': 'Thonglor - Eakkamai', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Jujiezz', 'lastName': 'J', 'countryCode': 'TH'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/38314881/list/thonglor--eakkamai', 'canonicalUrl': 'https://foursquare.com/user/38314881/list/thonglor--eakkamai', 'createdAt': 1390672044, 'updatedAt': 1423646383, 'followers': {'count': 0}, 'listItems': {'count': 18, 'items': [{'id': 'v526cc2c6498ea29948f9ce08', 'createdAt': 1390672128}]}}, {'id': '50f2fb33e4b0ff868411c127', 'name': 'To do list III', 'description': '', 'type': 'others', 'user': {'isSanctione ...
#                          ID                    Name  Likes  Rating  Tips
# 0  526cc2c6498ea29948f9ce08  50/50 Restaurant & Bar     11     7.1     2
# ( 17 / 17 ) processed
#    District                        ID                           Name Likes  \
# 0       NaN                         0                              0     0
# 1       NaN  4d4250008b88b1f70039ea33              Volcano (โวลคาโน)    12
# 2       NaN  4c0e4460b1b676b039bde186     Platform 1 (แพลตฟอร์ม วัน)    20
# 3       NaN  4e3a8d61a809ec55443c9e3c          Viva & Aviv The River    89
# 4       NaN  57ebdb93498e32e2e0d4662f  Cantina Wine Bar & Restaurant    27
#
#   Rating Tips        Disrict
# 0      0    0  Bang Kho Laem
# 1    7.5   18          Dusit
# 2    7.1   15          Dusit
# 3    7.6   37     Khlong San
# 4    7.9    9     Phaya Thai

# %%
#make a back-up in .csv file 
ita_rest_stats_bkk.to_csv('ita_rest_stats_bkk_csv.csv')

# %%
#check the data format
ita_rest_stats_bkk.shape
# Out:
# (17, 7)

# %%
#trasform data format
ita_rest_stats_bkk['Likes'] = ita_rest_stats_bkk['Likes'].astype('float64')
ita_rest_stats_bkk['Tips'] = ita_rest_stats_bkk['Tips'].astype('float64')
ita_rest_stats_bkk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  0 non-null      float64
#  1   ID        17 non-null     object
#  2   Name      17 non-null     object
#  3   Likes     17 non-null     float64
#  4   Rating    17 non-null     object
#  5   Tips      17 non-null     float64
#  6   Disrict   17 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 1.1+ KB

# %%
# Resturant with maximum Likes
ita_rest_stats_bkk.iloc[ita_rest_stats_bkk['Likes'].idxmax()]
# Out:
# District                         NaN
# ID          4e3a8d61a809ec55443c9e3c
# Name           Viva & Aviv The River
# Likes                             89
# Rating                           7.6
# Tips                              37
# Disrict                   Khlong San
# Name: 3, dtype: object

# %%
# Resturant with maximum Ratings
ita_rest_stats_bkk.iloc[ita_rest_stats_bkk['Rating'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-0f36600d8398> in <module>
#       1 # Resturant with maximum Ratings
# ----> 2 ita_rest_stats_bkk.iloc[ita_rest_stats_bkk['Rating'].idxmax()]
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2108         """
#    2109         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2110         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    2111         if i == -1:
#    2112             return np.nan
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      63                 f_name = f.__name__.replace("nan", "")
#      64                 raise TypeError(
# ---> 65                     f"reduction operation '{f_name}' not allowed for this dtype"
#      66                 )
#      67             try:
#
# TypeError: reduction operation 'argmax' not allowed for this dtype

# %%
#create a table groupping the district 
BKK_districts_stats=ita_rest_stats_bkk.groupby('Disrict',as_index=False).mean()[['Disrict','Rating']]
BKK_districts_stats.columns=['District','Average Rating']
BKK_districts_stats.sort_values(['Average Rating'],ascending=False).head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-f706c31d0e13> in <module>
#       1 #create a table groupping the district
# ----> 2 BKK_districts_stats=ita_rest_stats_bkk.groupby('Disrict',as_index=False).mean()[['Disrict','Rating']]
#       3 BKK_districts_stats.columns=['District','Average Rating']
#       4 BKK_districts_stats.sort_values(['Average Rating'],ascending=False).head(50)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['Rating'] not in index"

# %%
#create a table groupping the district 
BKK_districts_stats_L=ita_rest_stats_bkk.groupby('Disrict',as_index=False).mean()[['Disrict','Likes']]
BKK_districts_stats_L.columns=['District','Average Likes']
BKK_districts_stats_L.sort_values(['Average Likes'],ascending=False).head(50)
# Out:
#                 District  Average Likes
# 2             Khlong San      89.000000
# 9         Samphanthawong      89.000000
# 4           Phra Khanong      30.333333
# 3             Phaya Thai      27.000000
# 11              Watthana      26.000000
# 5            Phra Nakhon      18.500000
# 1                  Dusit      16.000000
# 10            Suan Luang       8.000000
# 6   Pom Prap Sattru Phai       7.000000
# 8            Ratchathewi       4.000000
# 0          Bang Kho Laem       0.000000
# 7             Rat Burana       0.000000

# %%
#Let's Visualize the distribution of the Rating
BKK_districts_stats.groupby('District')['Average Rating'].mean().plot.bar(figsize=(10,5), color=clr)
plt.title('Average Rating per District', fontsize = 20)
plt.xlabel('District', fontsize = 15)
plt.ylabel('Average Rating',fontsize = 15)
plt.legend()
plt.show()

# %%
#Let's Visualize the distribution of the Likes
BKK_districts_stats_L.groupby('District')['Average Likes'].mean().plot.bar(figsize=(10,5), color=clr)
plt.title('Average Likes per District', fontsize = 20)
plt.xlabel('District', fontsize = 15)
plt.ylabel('Average Likes',fontsize = 15)
plt.legend()
plt.show()
